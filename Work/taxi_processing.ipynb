# %%
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import datetime

# %%
numbers = ['С941НМ125',
            'С869НК125',
            'К614АН125',
            'Е377ВМ125',
            'О657МТ125',
            'С729МК125',
            'Р769КХ125',
            'Е677КК125',
            'У414КУ125',
            'М848КЕ125',
            'Н281АР125',
            'А274ТВ125',
            'В350КК125',
            'К166МН125',
            'О964ЕУ125',
            'У085НР125',
            'Х287МС125',
            'Е064НС125',
            'Т610МР125',
            'У118НХ125',
            'С613МН125',
            'В131МУ125',
            'Р447МО125',
            'С614ЕК125',
            'М131ЕЕ125',
            'В350ЕТ125',
            'М325АН125',
            'Е504АС125',
            'Т425КС125',
            'С203МН125',
            'Е425ЕУ125',
            'А614НЕ125',
            'М205КК125',
            'О495НУ125',
            'У047МС125',
            'Е328НО125',
            'В850ЕВ125',
            'М920МН125',
            'В574НХ125',
            'К348НК125',
            'О751МХ125',
            'Е943НР125',
            'С067ОВ125',
            'У788МВ125',
            'К924НО125',
            'С578МК125',
            'Н454МН125',
            'В465ТХ125',
            'Х513МА125',
            'Н953ОВ125',
            'Р850НТ125',
            'К208МС125',
            'Е323НТ125',
            'К070НЕ125',
            'О866МР125',
            'С854НВ125',
            'У386НР125',
            'В353ТВ125',
            'У104НВ125',
            'Т172МХ125',
            'В880НУ125',
            'У660ЕЕ125',
            'Т695МК125',
            'Р499ОЕ125',
            'У235МС125',
            'Е821МТ125',
            'У665УВ125',
            'Р137ОЕ125',
            'О845МТ125',
            'Х775НТ125',
            'Р736НС125',
            'М445МК125',
            'М139ММ125',
            'С967СС25',
            'О645ЕУ125',
            'Е392НО125',
            'Е388НТ125',
            'А046СО125',
            'Н956ЕН125',
            'У646КХ125',
            'М033МС125',
            'Е579ЕТ125',
            'С443КТ125',
            'В307КХ125',
            'У650НК125',
            'Т021КУ125',
            'М843МС125',
            'С916МО125',
            'К272НХ125',
            'К547МО125',
            'Е034ОА125',
            'А926НТ125',
            'С881ЕК125',
            'У704МО125',
            'У775НС125',
            'Н954НУ125',
            'Р481ВХ125',
            'О208МВ125',
            'А745КТ125',
            'К386МС125',
            'У667КР125',
            'Р397МУ125',
            'Х641НК125',
            'Х938МР125',
            'М965ОЕ125',
            'Р618МА125',
            'Х988АА125',
            'Х205МХ125',
            'С067ОВ125',
            'А894СО125',
            'О686КС125',
            'М924МР125',
            'Р809ЕЕ125',
            'Т532ЕТ125',
            'Е508МО125',
            'А696ТУ125',
            'Р242МР125',
            'Р754АС125',
            'К859ЕТ125',
            'С571МС125',
            'Т528НТ125',
            'Н678НЕ125',
            'Н769КО125',
            'У187КС125',
            'У171НУ125',
            'Х038НТ125',
            'Е264ВУ125',
            'М588НМ125',
            'Х391МН125',
            'Х340НС125',
            'В727НК125',
            'Р681МС125',
            'М880ОЕ125',
            'К507МТ125',
            'К388НК125',
            'Р001ОЕ98',
            'У715ОХ125',
            'У531КР125',
            'О637ВВ125',
            'С815ЕР125',
            'М500ЕН125',
            'В156КТ125',
            'А384ЕЕ125',
            'К472МР125',
            'С316КС125',
            'Р109МВ125',
            'Х096КВ125',
            'М050КУ125',
            'Н830НУ125',
            'А347КО125',
            'О755МН125',
            'К910ЕА125',
            'К178МТ125',
            'О966МА125',
            'У914МА125',
            'В465НС125',
            'С571КТ125',
            'М725МС125',
            'Т391НТ125',
            'У956МС125',
            'С219АА125',
            'Е722ХО125',
            'Е234АО125',
            'Т622КС125',
            'А423СТ125',
            'М463МТ125',
            'А331ТВ125',
            'Х781МА125',
            'Е176НУ125',
            'Р133НС125',
            'Х144ОА125',
            'Р746АТ125',
            'Н786НУ125',
            'О138ОА125',
            'К972КЕ125',
            'М091МХ125',
            'Е618НЕ125',
            'О035НР125',
            'О533НУ125',
            'О115НР125',
            'О496НС125',
            'К998МР125',
            'А032АХ125',
            'М416НР125',
            'У808КВ125',
            'М493МТ125',
            'Н551НМ125',
            'Х905МХ125',
            'К839АА125',
            'К746СА125',
            'К785МТ125',
            'М226МР125',
            'О880МН125',
            'О912МН125',
            'Р093НЕ125',
            'Х224МХ125',
            'М952АТ125',
            'Н088ЕХ125',
            'О616ОА125',
            'О279НЕ125',
            'Т951АТ125',
            'Х845НТ125',
            'А980НТ125',
            'О148МР125',
            'О601ОК125',
            'С251МН125',
            'О103МУ125',
            'В230КК125',
            'У418КЕ125',
            'Т629ОА125',
            'Х006МВ25',
            'Р078КН125',
            'М391ОА125',
            'С339КТ125',
            'Е037НХ125',
            'О998МУ125',
            'Н327ОВ125',
            'У543МО125',
            'Х723КТ125',
            'М263ОЕ125',
            'С897НР125',
            'М620ОЕ125',
            'С149МН125',
            'М351НМ125',
            'Т869КМ125',
            'О886МР125',
            'О024ОА125',
            'О549МК125',
            'М901МТ125',
            'В938НЕ125',
            'Р493МО125',
            'Н025ОВ125',
            'С978КУ125',
            'Е573МР125',
            'Н024МТ125',
            'О388ЕЕ125',
            'В403КК125',
            'Р237МХ125',
            'О775НР125',
            'У465ЕС125',
            'А988КМ125',
            'Р392МВ125',
            'М273ВТ125',
            'Н799ОВ125',
            'М574МР125',
            'С020МТ125',
            'С500ОХ125',
            'К445ЕВ125',
            'Р404АТ125',
            'С094ОА125',
            'А241МК125',
            'Е355НУ125',
            'О698ОВ125',
            'Н056ОЕ125',
            'У592ЕУ125',
            'А764ТЕ125',
            'О972ОА125',
            'А668НТ125',
            'В441МТ125',
            'Е155АН125',
            'А540МЕ125',
            'Р569МУ125',
            'В399КО125',
            'В825МВ125',
            'К386МС125',
            'Р110НМ125',
            'А838АТ125',
            'У595НМ125',
            'Е216ТВ125',
            'Н265ОВ125',
            'Р944ЕЕ125',
            'У440НМ125',
            'У031НС125',
            'М615НР125',
            'А809ОТ125',
            'О737АА125',
            'Н499КЕ125',
            'К754НР125',
            'У192АХ125',
            'Р653МХ125',
            'С120НО125',
            'Е655МТ125',
            'Х913ВН125',
            'Н679ОВ125',
            'Х395МТ125',
            'С523КА125',
            'О618НЕ125',
            'А682СН125',
            'О105МС125',
            'Р196ОВ125',
            'Р108ОВ125',
            'С654МН125',
            'В692МВ125',
            'Е022НЕ125',
            'Т047КО125',
            'У126МН125',
            'С332МК125',
            'А950СМ125',
            'О922МТ125',
            'Н243МН125',
            'В959АА125',
            'У343МА125',
            'С369АЕ125',
            'В143НО125',
            'О402МК125',
            'К378КР125',
            'О644МЕ125',
            'Н679ОК125',
            'М133КК125',
            'Е077НЕ125',
            'О693МР125',
            'У158НУ125',
            'Р282СА125',
            'Р112МС125',
            'М441ОЕ125',
            'У318КО125',
            'О280ОВ125',
            'А147МА125',
            'О367АО125',
            'А330СА125',
            'Т894МО125',
            'М647ОЕ125',
            'Р969МХ125',
            'Е784МН125',
            'У950ЕО125',
            'Н017ОЕ125',
            'У513ОВ125',
            'М312АХ125',
            'С071НТ125',
            'Е833НК125',
            'Т029АР125',
            'О873МХ125',
            'Е845ОЕ125',
            'М593ЕО125',
            'Е146КТ125',
            'Х249МР125',
            'К137ЕЕ125',
            'Н656НЕ125',
            'В744АУ125',
            'Р780НТ125',
            'О896ОВ125',
            'В053НЕ125',
            'К106АМ125',
            'У771АУ125',
            'В085НР125',
            'С486ЕР125',
            'А361СМ125',
            'Н810АК125',
            'Н125НЕ125',
            'А890НТ125',
            'А911МК125',
            'М637КЕ125',
            'В788КК125',
            'Е856АА125',
            'Т942ОВ125',
            'В996НХ125',
            'У520ОХ125',
            'Т498АТ125',
            'Е908АО125',
            'С199АА125',
            'У235НМ125',
            'С865МН125',
            'Р947АУ125',
            'У363ВО125',
            'Н509ОЕ125',
            'К124КЕ125',
            'М099НЕ125',
            'С963ОА125',
            'К740МР125',
            'Н214ОА125',
            'Р880АР125',
            'М707ОЕ125',
            'О480АХ125',
            'С045НЕ125',
            'О557КТ125',
            'О016НЕ125',
            'С957ОА125',
            'Т109НТ125',
            'А650ХО125',
            'К549НР125',
            'В159ТВ125',
            'М845ОА125',
            'У741НО125',
            'Х299НР125',
            'С697ЕН125',
            'М257МО125',
            'С298МО125',
            'О639МС125',
            'А674ТЕ125',
            'У589МВ125',
            'К201НС125',
            'О948НУ125',
            'Т849НУ125',
            'В525МЕ125',
            'Н381НК125',
            'С223КС125',
            'Х545НТ125',
            'Р410НТ125',
            'Е257ТВ125',
            'У494НВ125',
            'Т029АА125',
            'Х569ОЕ125',
            'А419МХ125',
            'Е598НЕ125',
            'А608АХ125',
            'К673КО125',
            'Р931НХ125',
            'У923НС125',
            'М816МА125',
            'В824МО125',
            'В135ТВ125',
            'М445ОЕ125',
            'О780КС125',
            'Р838ОЕ125',
            'К827МА125',
            'Е471ЕТ125',
            'О914МР125',
            'А984ОР125',
            'О378НР125',
            'В558ЕН125',
            'О780АР125',
            'О161НУ125',
            'У069КТ125',
            'Е443ВВ125',
            'В971АТ125',
            'О706ЕХ125',
            'Х309НТ125',
            'Н954НУ125',
            'Х382МР125',
            'Х768НВ125',
            'Н291МВ125',
            'Т123ОА125',
            'В690МО125',
            'Н416ОК125',
            'Х776ВВ125',
            'К420ТВ125',
            'Н734ОК125',
            'Е699НХ125',
            'М851АВ125',
            'Х479МХ125',
            'К134ЕЕ125',
            'М123МК125',
            'О530МТ125',
            'А046ХА125',
            'М078НМ125',
            'А858СО125',
            'Р894НМ125',
            'Е844НХ125',
            'У132КВ125',
            'О371НВ125',
            'Н487ОК125',
            'А312СК125',
            'Н690ОК125',
            'Н694ОК125',
            'О796ОК125',
            'Р634НВ125',
            'М713МС125',
            'У105НМ125',
            'О786ЕЕ125',
            'Р767АУ125',
            'Т143КО125',
            'Н316МК125',
            'Е340НС125',
            'С090НР125',
            'А286КК125',
            'У460ОВ125',
            'А916СМ125',
            'В103КК125',
            'С452МУ125',
            'Р506НК125',
            'Х344ОЕ125',
            'Н971КА125',
            'О540АК125',
            'А004СВ125',
            'С486МО125']

# %%
with open('dataTotal.html') as f:
   read_data = f.read()

# %%
soup = BeautifulSoup(read_data)
tables = soup.find_all('tr', {'class': 'item'}) #Получаем все таблицы с таблицу с параметрами

# %%
tableResult = np.empty(shape = (1,13), dtype = str)

for t in tables:
    soup = BeautifulSoup(str(t)) #Первая машина в таблице
    tablesInfo = soup.find_all('td')
    tablesInfoArray = np.char.replace(
                                      np.char.replace(
                                                      np.char.replace(np.array(list(map(str, np.array(tablesInfo, dtype=object)))), '<td>\n', ''),
                                                                                                                        '</td>', ''),
                                                                                                                '  ', '')
    try:
        for i in [4, 5, 6, 12]:
            soup = BeautifulSoup(str(tablesInfoArray[i]))
            toChange = soup.find_all('div', {'class': 'mobile-hidden'})
            tablesInfoArray[i] = np.char.replace(np.char.replace(toChange[0].contents[0], ' ', ''), '\n', '')
        tableResult = np.vstack((tableResult, tablesInfoArray))
    except Exception as err:
        error = tablesInfo
        print(err)
        notErrPrev = prev
    prev = tablesInfo

# %%
result = pd.DataFrame(tableResult[1:], columns = ['Полное наименование', 'Сокращенное наименование', 'ОГРН',
                                                  'Номер разрешения', 'Дата внесения реестровой записи о выдаче разрешения',
                                                  'Дата начала действия разрешения', 'Срок действия разрешения',
                                                  'Серия и номер бланка разрешения', 'Марка автомобиля', 'Модель автомобиля',
                                                  'Государственный номер', 'Признак аннулирования', 'Дата аннулирования'])

# %%
mask = result['Номер разрешения'].str.contains(r'Укажите номер разрешения', na=True)
result.loc[mask, 'Номер разрешения'] = result.loc[mask, 'Номер разрешения'].replace('Укажите номер разрешения', '-')
for c in ['Полное наименование', 'Сокращенное наименование', 'Серия и номер бланка разрешения',
          'Марка автомобиля', 'Модель автомобиля', 'Государственный номер', 'Признак аннулирования']:
    result[c] = result[c].astype(str)
for c in ['ОГРН', 'Номер разрешения']:
    result[c] = result[c].astype(str)
for c in ['Дата внесения реестровой записи о выдаче разрешения', 'Дата начала действия разрешения',
          'Срок действия разрешения', 'Дата аннулирования']:
    result.loc[~result[c].isin(['']), c] = pd.to_datetime(result.loc[~result[c].isin(['']), c], format = '%d.%m.%Y').dt.date

# %%
mask = result['Государственный номер'].str.contains(r' ', na=True)
result.loc[mask, 'Государственный номер'] = result.loc[mask, 'Государственный номер'].replace(to_replace=' ', value='', regex=True)

# %%
mask = result['Государственный номер'].str.contains(r'RUS', na=True)
result.loc[mask, 'Государственный номер'] = result.loc[mask, 'Государственный номер'].replace(to_replace='RUS', value='', regex=True)

# %%
#result = result.convert_dtypes()

# %%
#pd.to_datetime(result[~result['Дата внесения реестровой записи о выдаче разрешения'].isin([''])]['Дата внесения реестровой записи о выдаче разрешения'], format = '%d.%m.%Y')

# %%
result.tail(5)
# Out:
#                                    Полное наименование  \
# 522  Индивидуальный предприниматель Киселев Андрей ...
# 523  Индивидуальный предпринимательСоловых Илья Анд...
# 524                                       ООО "Ксения"
# 525                                      ООО "АДМИРАЛ"
# 526  Индивидуальный предприниматель Киселев Андрей ...
#
#     Сокращенное наименование             ОГРН Номер разрешения  \
# 522                           315250700000600            11532
# 523                           318253600001676            13280
# 524                             1092538005889            11121
# 525                             1162536058673             7727
# 526                           315250700000600             9347
#
#     Дата внесения реестровой записи о выдаче разрешения  \
# 522                                         2019-02-11
# 523                                         2019-08-12
# 524                                         2018-12-29
# 525                                         2018-01-22
# 526                                         2018-06-18
#
#     Дата начала действия разрешения Срок действия разрешения  \
# 522                      2019-02-08               2024-02-08
# 523                      2019-08-09               2024-08-09
# 524                      2018-12-29               2023-12-29
# 525                      2018-01-19               2023-01-19
# 526                      2018-06-15               2023-06-15
#
#     Серия и номер бланка разрешения Марка автомобиля Модель автомобиля  \
# 522                       ПК 027683           NISSAN              NOTE
# 523                       ПК 029425       MITSUBISHI          FUNCARGO
# 524                       ПК 027272           TOYOTA          FUNCARGO
# 525                       ПК 022776            HONDA             PASSO
# 526                       ПК 025596            HONDA             TEANA
#
#     Государственный номер Признак аннулирования Дата аннулирования
# 522             Р506НК125                    Да
# 523             Н971КА125                    Да         2021-03-15
# 524             Н971КА125                    Да
# 525             О540АК125                    Да         2021-04-26
# 526             С486МО125                    Да

# %%
#~((result['Признак аннулирования'] == 'Да') & (result['Государственный номер'].isin(numbers))) &

# %%
uniqueNumbers = result[result['Государственный номер'].isin(numbers)]['Государственный номер'].unique()
missing = np.setdiff1d(numbers, uniqueNumbers)

# %%
uniqueNumbers
# Out:
# array(['С941НМ125', 'С869НК125', 'К614АН125', 'Е377ВМ125', 'О657МТ125',
#        'С729МК125', 'Р769КХ125', 'Е677КК125', 'У414КУ125', 'М848КЕ125',
#        'Н281АР125', 'А274ТВ125', 'В350КК125', 'К166МН125', 'О964ЕУ125',
#        'У085НР125', 'Х287МС125', 'Е064НС125', 'Т610МР125', 'У118НХ125',
#        'С613МН125', 'В131МУ125', 'Р447МО125', 'С614ЕК125', 'М131ЕЕ125',
#        'В350ЕТ125', 'М325АН125', 'Е504АС125', 'Т425КС125', 'С203МН125',
#        'Е425ЕУ125', 'А614НЕ125', 'М205КК125', 'О495НУ125', 'У047МС125',
#        'Е328НО125', 'В850ЕВ125', 'М920МН125', 'В574НХ125', 'К348НК125',
#        'О751МХ125', 'Е943НР125', 'С067ОВ125', 'У788МВ125', 'К924НО125',
#        'С578МК125', 'Н454МН125', 'В465ТХ125', 'Х513МА125', 'Н953ОВ125',
#        'Р850НТ125', 'К208МС125', 'Е323НТ125', 'К070НЕ125', 'О866МР125',
#        'С854НВ125', 'У386НР125', 'В353ТВ125', 'У104НВ125', 'Т172МХ125',
#        'В880НУ125', 'У660ЕЕ125', 'Т695МК125', 'Р499ОЕ125', 'У235МС125',
#        'Е821МТ125', 'У665УВ125', 'Р137ОЕ125', 'О845МТ125', 'Х775НТ125',
#        'Р736НС125', 'М445МК125', 'М139ММ125', 'О645ЕУ125', 'Е388НТ125',
#        'А046СО125', 'Н956ЕН125', 'У646КХ125', 'М033МС125', 'Е579ЕТ125',
#        'С443КТ125', 'В307КХ125', 'У650НК125', 'Т021КУ125', 'М843МС125',
#        'С916МО125', 'К272НХ125', 'К547МО125', 'Е034ОА125', 'А926НТ125',
#        'С881ЕК125', 'У704МО125', 'У775НС125', 'Н954НУ125', 'Р481ВХ125',
#        'О208МВ125', 'А745КТ125', 'К386МС125', 'У667КР125', 'Р397МУ125',
#        'Х641НК125', 'Х938МР125', 'М965ОЕ125', 'Р618МА125', 'Х988АА125',
#        'Х205МХ125', 'А894СО125', 'О686КС125', 'М924МР125', 'Р809ЕЕ125',
#        'Т532ЕТ125', 'Е508МО125', 'А696ТУ125', 'Р242МР125', 'Р754АС125',
#        'К859ЕТ125', 'С571МС125', 'Т528НТ125', 'Н678НЕ125', 'Н769КО125',
#        'У187КС125', 'У171НУ125', 'Х038НТ125', 'Е264ВУ125', 'М588НМ125',
#        'Х391МН125', 'Х340НС125', 'В727НК125', 'Р681МС125', 'М880ОЕ125',
#        'К507МТ125', 'К388НК125', 'У715ОХ125', 'У531КР125', 'О637ВВ125',
#        'С815ЕР125', 'М500ЕН125', 'В156КТ125', 'А384ЕЕ125', 'К472МР125',
#        'Р109МВ125', 'Х096КВ125', 'М050КУ125', 'Н830НУ125', 'А347КО125',
#        'О755МН125', 'К910ЕА125', 'К178МТ125', 'О966МА125', 'У914МА125',
#        'В465НС125', 'С571КТ125', 'М725МС125', 'Т391НТ125', 'У956МС125',
#        'С219АА125', 'Е722ХО125', 'Е234АО125', 'Т622КС125', 'А423СТ125',
#        'М463МТ125', 'А331ТВ125', 'Х781МА125', 'Е176НУ125', 'Р133НС125',
#        'Х144ОА125', 'Р746АТ125', 'Н786НУ125', 'О138ОА125', 'К972КЕ125',
#        'М091МХ125', 'Е618НЕ125', 'О035НР125', 'О533НУ125', 'О115НР125',
#        'О496НС125', 'К998МР125', 'А032АХ125', 'М416НР125', 'У808КВ125',
#        'М493МТ125', 'Н551НМ125', 'Х905МХ125', 'К839АА125', 'К746СА125',
#        'К785МТ125', 'М226МР125', 'О880МН125', 'О912МН125', 'Р093НЕ125',
#        'Х224МХ125', 'М952АТ125', 'Н088ЕХ125', 'О616ОА125', 'О279НЕ125',
#        'Т951АТ125', 'Х845НТ125', 'А980НТ125', 'О148МР125', 'О601ОК125',
#        'О103МУ125', 'В230КК125', 'У418КЕ125', 'Т629ОА125', 'Р078КН125',
#        'С339КТ125', 'О998МУ125', 'Х723КТ125', 'М263ОЕ125', 'С897НР125',
#        'М620ОЕ125', 'С149МН125', 'М351НМ125', 'Т869КМ125', 'О886МР125',
#        'О024ОА125', 'О549МК125', 'М901МТ125', 'В938НЕ125', 'Р493МО125',
#        'С978КУ125', 'Е573МР125', 'Н024МТ125', 'О388ЕЕ125', 'В403КК125',
#        'Р237МХ125', 'О775НР125', 'У465ЕС125', 'М273ВТ125', 'Н799ОВ125',
#        'М574МР125', 'С020МТ125', 'Р404АТ125', 'С094ОА125', 'А241МК125',
#        'О698ОВ125', 'Н056ОЕ125', 'У592ЕУ125', 'А764ТЕ125', 'О972ОА125',
#        'А668НТ125', 'В441МТ125', 'Е155АН125', 'А540МЕ125', 'Р569МУ125',
#        'В399КО125', 'В825МВ125', 'У595НМ125', 'Е216ТВ125', 'Р944ЕЕ125',
#        'У440НМ125', 'У031НС125', 'М615НР125', 'А809ОТ125', 'О737АА125',
#        'Н499КЕ125', 'К754НР125', 'У192АХ125', 'Р653МХ125', 'С120НО125',
#        'Е655МТ125', 'Х913ВН125', 'Н679ОВ125', 'Х395МТ125', 'С523КА125',
#        'О618НЕ125', 'А682СН125', 'О105МС125', 'Р196ОВ125', 'С654МН125',
#        'В692МВ125', 'Е022НЕ125', 'Т047КО125', 'У126МН125', 'С332МК125',
#        'А950СМ125', 'О922МТ125', 'Н243МН125', 'В959АА125', 'У343МА125',
#        'К378КР125', 'О644МЕ125', 'Н679ОК125', 'М133КК125', 'Е077НЕ125',
#        'О693МР125', 'У158НУ125', 'Р112МС125', 'М441ОЕ125', 'У318КО125',
#        'О280ОВ125', 'А147МА125', 'А330СА125', 'Т894МО125', 'Е784МН125',
#        'У950ЕО125', 'У513ОВ125', 'М312АХ125', 'С071НТ125', 'Е833НК125',
#        'Т029АР125', 'О873МХ125', 'Е845ОЕ125', 'М593ЕО125', 'Е146КТ125',
#        'Х249МР125', 'Н656НЕ125', 'Р780НТ125', 'О896ОВ125', 'В053НЕ125',
#        'К106АМ125', 'У771АУ125', 'В085НР125', 'С486ЕР125', 'А361СМ125',
#        'Н125НЕ125', 'А890НТ125', 'А911МК125', 'М637КЕ125', 'В788КК125',
#        'Т942ОВ125', 'У520ОХ125', 'Т498АТ125', 'Е908АО125', 'С199АА125',
#        'У235НМ125', 'С865МН125', 'Р947АУ125', 'У363ВО125', 'Н509ОЕ125',
#        'С963ОА125', 'К740МР125', 'Н214ОА125', 'Р880АР125', 'М707ОЕ125',
#        'О480АХ125', 'С045НЕ125', 'О557КТ125', 'Т109НТ125', 'А650ХО125',
#        'В159ТВ125', 'М845ОА125', 'У741НО125', 'Х299НР125', 'С697ЕН125',
#        'М257МО125', 'С298МО125', 'О639МС125', 'У589МВ125', 'К201НС125',
#        'Т849НУ125', 'В525МЕ125', 'Н381НК125', 'С223КС125', 'Х545НТ125',
#        'Р410НТ125', 'Е257ТВ125', 'У494НВ125', 'Х569ОЕ125', 'А419МХ125',
#        'Е598НЕ125', 'А608АХ125', 'К673КО125', 'Р931НХ125', 'У923НС125',
#        'В824МО125', 'В135ТВ125', 'Р838ОЕ125', 'К827МА125', 'Е471ЕТ125',
#        'О914МР125', 'В558ЕН125', 'О161НУ125', 'У069КТ125', 'Е443ВВ125',
#        'В971АТ125', 'О706ЕХ125', 'Х309НТ125', 'Х382МР125', 'Х768НВ125',
#        'Н291МВ125', 'Т123ОА125', 'В690МО125', 'Х776ВВ125', 'К420ТВ125',
#        'Н734ОК125', 'Е699НХ125', 'М851АВ125', 'Х479МХ125', 'К134ЕЕ125',
#        'М123МК125', 'О530МТ125', 'А046ХА125', 'М078НМ125', 'А858СО125',
#        'Р894НМ125', 'У132КВ125', 'О371НВ125', 'Н487ОК125', 'Н690ОК125',
#        'Н694ОК125', 'О796ОК125', 'Р634НВ125', 'М713МС125', 'У105НМ125',
#        'О786ЕЕ125', 'Р767АУ125', 'Т143КО125', 'Н316МК125', 'Е340НС125',
#        'С090НР125', 'А286КК125', 'У460ОВ125', 'А916СМ125', 'В103КК125',
#        'С452МУ125', 'Р506НК125', 'Н971КА125', 'О540АК125', 'С486МО125'],
#       dtype=object)

# %%
missing
# Out:
# array(['А004СВ125', 'А312СК125', 'А674ТЕ125', 'А838АТ125', 'А984ОР125',
#        'А988КМ125', 'В143НО125', 'В744АУ125', 'В996НХ125', 'Е037НХ125',
#        'Е355НУ125', 'Е392НО125', 'Е844НХ125', 'Е856АА125', 'К124КЕ125',
#        'К137ЕЕ125', 'К445ЕВ125', 'К549НР125', 'М099НЕ125', 'М391ОА125',
#        'М445ОЕ125', 'М647ОЕ125', 'М816МА125', 'Н017ОЕ125', 'Н025ОВ125',
#        'Н265ОВ125', 'Н327ОВ125', 'Н416ОК125', 'Н810АК125', 'О016НЕ125',
#        'О367АО125', 'О378НР125', 'О402МК125', 'О780АР125', 'О780КС125',
#        'О948НУ125', 'Р001ОЕ98 ', 'Р108ОВ125', 'Р110НМ125', 'Р282СА125',
#        'Р392МВ125', 'Р969МХ125', 'С251МН125', 'С316КС125', 'С369АЕ125',
#        'С500ОХ125', 'С957ОА125', 'С967СС25 ', 'Т029АА125', 'У543МО125',
#        'Х006МВ25 ', 'Х344ОЕ125'], dtype='<U9')

# %%
dfBad = result[(result['Признак аннулирования'] == 'Нет') &
       (result['Государственный номер'].isin(numbers)) &
       (pd.to_datetime(result['Срок действия разрешения'], format = '%Y-%m-%d').dt.date > datetime.date(2022, 6, 16))]

# %%
dfBad
# Out:
#                                    Полное наименование  \
# 3    Индивидуальный предприниматель Галай Олег Влад...
# 6    Индивидуальный предприниматель Грачева Надежда...
# 28                                       ООО "Априори"
# 30                                          ООО "ИНКО"
# 68   Индивидуальный предприниматель Кайгородова Ека...
# 72                                          ООО "ИНКО"
# 80                                          ООО "ИНКО"
# 82                                 ООО "ДВДЕВЕЛОПМЕНТ"
# 90   Индивидуальный предприниматель Мушарапова Елен...
# 91                                   ООО "Техпрогресс"
# 98   Индивидуальный предприниматель Старовойтов Вла...
# 109                                      ООО "АБОРДАЖ"
# 111                                         ООО "ИНКО"
# 119                                      ООО "Биллион"
# 127                                    ООО "Статус ДВ"
# 129                                      ООО "Априори"
# 144                                        ООО "СТАРК"
# 152                                         ООО "ИНКО"
# 153  Индивидуальный предприниматель Корытко Анастас...
# 157  Индивидуальный предприниматель Латушкина Яна В...
# 158  Индивидуальный предприниматель Ильюшенко Алекс...
# 173  Индивидуальный предпринимательКраснощеков Конс...
# 198  Индивидуальный предпринимательДроздов Сергей И...
# 218  Индивидуальный предприниматель Ли Леонид Робер...
# 239                                        ООО "СТАРК"
# 248                                      ООО "Априори"
# 263                           ООО "Кристальный родник"
# 269  Индивидуальный предприниматель Шеремета Евгени...
# 276                                      ООО "ФОРТУНА"
# 297  Индивидуальный предприниматель Пиминов Алексан...
# 299                                      ООО "ПРЕМИУМ"
# 302  Индивидуальный предприниматель Барило Евгений ...
# 304                                      ООО "Априори"
# 310  Индивидуальный предприниматель Евтеев Ярослав ...
# 315  Индивидуальный предприниматель Ключин Владимир...
# 321                                      ООО "Априори"
# 394                                      ООО "ФОРТУНА"
# 398                                        ООО "СТАРК"
# 403                                      ООО "Априори"
# 405  Индивидуальный предприниматель Ковальчук Серге...
# 445  Индивидуальный предприниматель Пронин Алексей ...
# 448  Индивидуальный предприниматель Краснощеков Кон...
# 472  Индивидуальный предпринимательДроздов Сергей И...
# 504                                      ООО "Априори"
# 506                                      ООО "Априори"
# 512                                        ООО "СТАРК"
# 520                                 ООО "ВЛАДМОТОПЛЮС"
#
#         Сокращенное наименование             ОГРН Номер разрешения  \
# 3                                 305251134200059            12565
# 6                                 317272400017170            13360
# 28                                  1172536037645            13257
# 30                                  1182536008225            10544
# 68                                319253600029846            12180
# 72                                  1182536008225             8897
# 80                                  1182536008225            10168
# 82                                  1162536075415             6774
# 90                                304250233100137            13855
# 91                                  1162536058541            11579
# 98                                314251115700072             9303
# 109                                 1162536067858            13433
# 111                                 1182536008225             9335
# 119                                 1042503451231            14879
# 127                                 1192536007861            12822
# 129                                 1172536037645            13346
# 144                                 1172536034549            11730
# 152                                 1182536008225            11237
# 153                               318253600018673            12779
# 157                               319253600026336            13949
# 158                               306250129700018             6639
# 173                               317253600010578             9010
# 198                               309253723000021            13950
# 218                               310251107600039            10595
# 239                                 1172536034549            10930
# 248                                 1172536037645            13581
# 263                                 1112539002542             9211
# 269                               318253600020872             8424
# 276                                 1162536080431             8945
# 297                               316253600092842            14737
# 299                                 1172536045032            11408
# 302  ИП Барило Евгений Сергеевич  305250206300011            17087
# 304                                 1172536037645            14480
# 310                               319253600078217            13412
# 315                               319253600032836            12208
# 321                                 1172536037645            15047
# 394                                 1162536080431             9696
# 398                                 1172536034549            10200
# 403                                 1172536037645            14471
# 405                               316250100053691             8109
# 445                               319253600002361            12766
# 448                               317253600010578            11938
# 472                               309253723000021            11374
# 504                                 1172536037645            15063
# 506                                 1172536037645            15482
# 512                                 1172536034549            13193
# 520                                 1172536015486            10111
#
#     Дата внесения реестровой записи о выдаче разрешения  \
# 3                                           2019-05-27
# 6                                           2019-08-26
# 28                                          2019-08-05
# 30                                          2018-11-09
# 68                                          2019-04-15
# 72                                          2018-05-03
# 80                                          2018-09-24
# 82                                          2017-11-13
# 90                                          2019-10-04
# 91                                          2019-03-04
# 98                                          2018-06-18
# 109                                         2019-08-26
# 111                                         2018-06-18
# 119                                         2020-04-06
# 127                                         2019-07-08
# 129                                         2019-08-26
# 144                                         2019-03-04
# 152                                         2019-01-18
# 153                                         2019-06-17
# 157                                         2019-11-11
# 158                                         2017-10-23
# 173                                         2018-05-21
# 198                                         2019-11-11
# 218                                         2018-11-16
# 239                                         2018-12-24
# 248                                         2019-09-13
# 263                                         2018-06-22
# 269                                         2018-04-02
# 276                                         2018-05-14
# 297                                         2020-02-17
# 299                                         2019-02-11
# 302                                         2020-12-21
# 304                                         2019-12-27
# 310                                         2019-08-19
# 315                                         2019-04-29
# 321                                         2020-04-06
# 394                                         2018-08-06
# 398                                         2018-09-24
# 403                                         2019-12-27
# 405                                         2018-03-02
# 445                                         2019-06-17
# 448                                         2019-04-15
# 472                                         2019-03-18
# 504                                         2020-04-06
# 506                                         2020-04-27
# 512                                         2019-08-05
# 520                                         2018-09-24
#
#     Дата начала действия разрешения Срок действия разрешения  \
# 3                        2019-05-24               2024-05-24
# 6                        2019-08-23               2024-08-23
# 28                       2019-08-02               2024-08-02
# 30                       2018-11-09               2023-11-09
# 68                       2019-04-12               2024-04-12
# 72                       2018-04-28               2023-04-20
# 80                       2018-09-21               2023-09-21
# 82                       2017-10-20               2022-10-20
# 90                       2019-10-04               2024-10-04
# 91                       2019-02-15               2024-02-15
# 98                       2018-06-15               2023-06-15
# 109                      2019-07-26               2024-07-26
# 111                      2018-06-15               2023-06-15
# 119                      2020-02-28               2025-02-28
# 127                      2019-06-21               2024-06-21
# 129                      2019-07-26               2024-07-26
# 144                      2019-03-01               2024-03-01
# 152                      2019-01-18               2024-01-18
# 153                      2019-06-14               2024-06-14
# 157                      2019-10-18               2024-10-18
# 158                      2017-10-05               2022-10-05
# 173                      2018-05-18               2023-05-18
# 198                      2019-10-18               2024-10-18
# 218                      2018-11-09               2023-11-09
# 239                      2018-12-21               2023-12-21
# 248                      2019-09-13               2024-09-13
# 263                      2018-06-09               2023-06-09
# 269                      2018-03-23               2023-03-23
# 276                      2018-05-11               2023-05-11
# 297                      2020-02-14               2025-02-14
# 299                      2019-02-01               2024-02-01
# 302                      2020-12-21               2025-12-21
# 304                      2019-12-27               2024-12-27
# 310                      2019-08-16               2024-08-16
# 315                      2019-04-26               2024-04-26
# 321                      2020-04-03               2025-04-03
# 394                      2018-08-03               2023-08-03
# 398                      2018-09-21               2023-09-21
# 403                      2019-12-27               2024-12-27
# 405                      2018-02-22               2023-02-22
# 445                      2019-06-14               2024-06-14
# 448                      2019-04-05               2024-04-05
# 472                      2019-02-01               2024-02-01
# 504                      2020-04-03               2025-04-03
# 506                      2020-04-24               2025-04-24
# 512                      2019-08-02               2024-08-02
# 520                      2018-09-21               2023-09-21
#
#     Серия и номер бланка разрешения Марка автомобиля Модель автомобиля  \
# 3                         ПК 028715           TOYOTA              NOAH
# 6                         ПК 029505            HONDA               FIT
# 28                        ПК 029402           TOYOTA        SAI HYBRID
# 30                        ПК 026695           TOYOTA             PRIUS
# 68                        ПК 028331           TOYOTA         PRIUS PHV
# 72                        ПК 025146            HONDA               FIT
# 80                        ПК 026319           TOYOTA             PRIUS
# 82                        ПК 021797           TOYOTA                AD
# 90                        ПК 029900           TOYOTA      COROLLA AXIO
# 91                        ПК 027730           TOYOTA              AQUA
# 98                        ПК 025552           TOYOTA            PROBOX
# 109                       ПК 029569           TOYOTA             PASSO
# 111                       ПК 025584           TOYOTA             PRIUS
# 119                       ПК 032990           NISSAN            SIENTA
# 127                       ПК 028972           NISSAN       TIIDA LATIO
# 129                       ПК 029591           TOYOTA   COROLLA FIELDER
# 144                       ПК 027881           NISSAN            RACTIS
# 152                       ПК 027388           TOYOTA              AQUA
# 153                       ПК 028929           TOYOTA              AQUA
# 157                       ПК 029994           TOYOTA  PRIUS RHV HYBRID
# 158                       ПК 021660           TOYOTA             IPSUM
# 173                       ПК 025259           TOYOTA             BELTA
# 198                       ПК 029995           TOYOTA             BELTA
# 218                       ПК 026746           TOYOTA             PASSO
# 239                       ПК 027081           NISSAN              CUBE
# 248                       ПК 029726            HONDA               FIT
# 263                       ПК 025460           NISSAN              VITZ
# 269                       ПК 023473           TOYOTA       PRIUSHYBRID
# 276                       ПК 025194           TOYOTA       COROLLAAXIO
# 297                       ПК 032848           TOYOTA      PRIUS HYBRID
# 299                       ПК 027559           TOYOTA   COROLLA FIELDER
# 302                       ПК 035286           Тойота             Приус
# 304                       ПК 030523            HONDA        FIT HYBRID
# 310                       ПК 029557           NISSAN              NOTR
# 315                       ПК 028358           NISSAN             TIIDA
# 321                       ПК 033159           TOYOTA             PRIUS
# 394                       ПК 025946           TOYOTA              NOAH
# 398                       ПК 026351           TOYOTA          FUNGARGO
# 403                       ПК 030514           TOYOTA             PRIUS
# 405                       ПК 023158            HONDA           AIRWAVE
# 445                       ПК 028916           NISSAN           CARAVAN
# 448                       ПК 028089           TOYOTA            RACTIS
# 472                       ПК 027525           TOYOTA             BELTA
# 504                       ПК 033175           TOYOTA   COROLLA FIELDER
# 506                       ПК 033593           TOYOTA    COROLLA AXIO H
# 512                       ПК 029338           TOYOTA          FUNCARGO
# 520                       ПК 026262            HONDA               FIT
#
#     Государственный номер Признак аннулирования Дата аннулирования
# 3               С941НМ125                   Нет
# 6               Е377ВМ125                   Нет
# 28              У118НХ125                   Нет
# 30              В131МУ125                   Нет
# 68              Р850НТ125                   Нет
# 72              К070НЕ125                   Нет
# 80              В880НУ125                   Нет
# 82              Т695МК125                   Нет
# 90              Х775НТ125                   Нет
# 91              Р736НС125                   Нет
# 98              А046СО125                   Нет
# 109             С916МО125                   Нет
# 111             К547МО125                   Нет
# 119             У775НС125                   Нет
# 127             У667КР125                   Нет
# 129             Х641НК125                   Нет
# 144             Е508МО125                   Нет
# 152             Н678НЕ125                   Нет
# 153             Н769КО125                   Нет
# 157             Х038НТ125                   Нет
# 158             Е264ВУ125                   Нет
# 173             М500ЕН125                   Нет
# 198             С219АА125                   Нет
# 218             О115НР125                   Нет
# 239             Р093НЕ125                   Нет
# 248             А980НТ125                   Нет
# 263             Х723КТ125                   Нет
# 269             С149МН125                   Нет
# 276             М901МТ125                   Нет
# 297             С020МТ125                   Нет
# 299             Р404АТ125                   Нет
# 302             А241МК125                   Нет
# 304             О698ОВ125                   Нет
# 310             А668НТ125                   Нет
# 315             Р569МУ125                   Нет
# 321             Е216ТВ125                   Нет
# 394             Н656НЕ125                   Нет
# 398             К106АМ125                   Нет
# 403             Н125НЕ125                   Нет
# 405             А911МК125                   Нет
# 445             У589МВ125                   Нет
# 448             В525МЕ125                   Нет
# 472             У069КТ125                   Нет
# 504             Н690ОК125                   Нет
# 506             О796ОК125                   Нет
# 512             Т143КО125                   Нет
# 520             В103КК125                   Нет

# %%
dfBad.to_csv('taxiBadFiltered.csv', header = True)

# %%
result.to_csv('taxiAll.csv', header = True)

# %%
dfBad.to_excel('taxiBadFiltered.xlsx', header = True)

# %%
result.to_excel('taxiAll.xlsx', header = True)
